# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_parquet("datasets/data-0-0.parquet.gzip")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50243 entries, 0 to 50242
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   vin                       50243 non-null  object
#  1   collect_ts                50243 non-null  int64
#  2   uuid                      50243 non-null  object
#  3   model_name                50243 non-null  object
#  4   series_code               50243 non-null  object
#  5   msg_create_time           50243 non-null  object
#  6   BCM_ebs_U_BATT            4508 non-null   float32
#  7   BCM_ebs_SOC               4508 non-null   float32
#  8   BCM_ebs_SOH_SUL           4508 non-null   float32
#  9   ebs_Q_Charge              4508 non-null   float32
#  10  ebs_Q_Discharge           4508 non-null   float32
#  11  BCM_ebs_SOC_STATE         4508 non-null   float32
#  12  BCM_ebs_SOH_SUL_STATE     4508 non-null   float32
# ...

# %%
# %matplotlib inline   # only in a Jupyter notebook
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
plt.show()
