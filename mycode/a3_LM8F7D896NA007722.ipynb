# %%
import numpy as np
import pandas as pd

data_raw = pd.read_parquet("vhrdata").drop_duplicates(subset=None, keep='last', inplace=False)
drop_columns = ["ebs_Q_Charge", "ebs_Q_Discharge", "BCM_ebs_I_BATT", "dcdc_OverTemperature","IC_LowBatteryvoltage", "DCDC_realInputVoltage", "DCDC_realInputCurrent"]
data_raw = data_raw.drop(columns=drop_columns)
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3207576 entries, 0 to 3207575
# Data columns (total 46 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   vin                       object
#  1   collect_ts                int64
#  2   uuid                      object
#  3   model_name                object
#  4   series_code               object
#  5   msg_create_time           object
#  6   vcu_VehicleMode           float32
#  7   vcu_vehicleSpeed          float32
#  8   VCU_VehicleSpeedValid     float32
#  9   vcu_state                 float32
#  10  bms_SOC                   float32
#  11  bms_state                 float32
#  12  BCM_ebs_U_BATT            float32
#  13  BCM_ebs_SOC               float32
#  14  BCM_ebs_SOH_SUL           float32
#  15  BCM_ebs_SOC_STATE         float32
#  16  BCM_ebs_SOH_SUL_STATE     float32
#  17  bcm_12VBatterySOC         float32
#  18  dcdc_realOutputVoltage    float32
#  19  dcdc_realOutputCurrent    float32
#  20  DCDC_AlerState            float32
#  21  DCDC_OutPwr               float32
#  22  DCDC_MaxPwrTime           float32
#  23  vcu_dcdc_enable           float32
#  24  vcu_dcdc_voltageReq       float32
#  25  DCDC_MCU_HVIL_Warning     float32
#  26  DCDC_BMS_HVIL_Warning     float32
#  27  DCDC_HV_InterlockStatus1  float32
#  28  DCDC_HV_InterlockStatus   float32
#  29  dcdc_systemStatus         float32
#  30  dcdc_deratingStatus       float32
#  31  dcdc_realTemperature      float32
#  32  BCM_EBSHvoffset           float32
#  33  bcm_pepsPowerMode         float32
#  34  bms_iLimitDrive           float32
#  35  bms_iLimitRegen           float32
#  36  bms_pLimitDrive           float32
#  37  bms_pLimitRegen           float32
#  38  bcm_HvOnRequest           float32
#  39  esc_vehicleSpeed          float32
#  40  esc_vehicleSpeedValid     float32
#  41  ac_ambientTemp            float32
#  42  ac_ambientTempValid       float32
#  43  vcu_highVoltageIndicator  float32
#  44  bcm_HvOffRequest          float32
#  45  BCM_EBS_State             float32
# dtypes: float32(40), int64(1), object(5)
# memory usage: 636.3+ MB

# %%
data_raw.head(20)

# %%
# 填充操作
data= data_raw[data_raw.vin == 'LM8F7D896NA007722'].fillna(method='ffill').sort_values(by="collect_ts")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301393 entries, 519066 to 1608673
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   vin                       301393 non-null  object
#  1   collect_ts                301393 non-null  int64
#  2   uuid                      301393 non-null  object
#  3   model_name                301393 non-null  object
#  4   series_code               301393 non-null  object
#  5   msg_create_time           301393 non-null  object
#  6   vcu_VehicleMode           301393 non-null  float32
#  7   vcu_vehicleSpeed          301393 non-null  float32
#  8   VCU_VehicleSpeedValid     301393 non-null  float32
#  9   vcu_state                 301393 non-null  float32
#  10  bms_SOC                   301393 non-null  float32
#  11  bms_state                 301393 non-null  float32
#  12  BCM_ebs_U_BATT            301384 non-null  float32
#  13  BCM_ebs_SOC               301384 non-null  float32
#  14  BCM_ebs_SOH_SUL           301384 non-null  float32
#  15  BCM_ebs_SOC_STATE         301384 non-null  float32
#  16  BCM_ebs_SOH_SUL_STATE     301384 non-null  float32
#  17  bcm_12VBatterySOC         301384 non-null  float32
#  18  dcdc_realOutputVoltage    301393 non-null  float32
#  19  dcdc_realOutputCurrent    301393 non-null  float32
#  20  DCDC_AlerState            301393 non-null  float32
#  21  DCDC_OutPwr               301393 non-null  float32
#  22  DCDC_MaxPwrTime           301393 non-null  float32
#  23  vcu_dcdc_enable           301393 non-null  float32
#  24  vcu_dcdc_voltageReq       301393 non-null  float32
#  25  DCDC_MCU_HVIL_Warning     301393 non-null  float32
#  26  DCDC_BMS_HVIL_Warning     301393 non-null  float32
#  27  DCDC_HV_InterlockStatus1  301393 non-null  float32
#  28  DCDC_HV_InterlockStatus   301393 non-null  float32
#  29  dcdc_systemStatus         301393 non-null  float32
#  30  dcdc_deratingStatus       301393 non-null  float32
#  31  dcdc_realTemperature      301393 non-null  float32
#  32  BCM_EBSHvoffset           301384 non-null  float32
#  33  bcm_pepsPowerMode         301384 non-null  float32
#  34  bms_iLimitDrive           301393 non-null  float32
#  35  bms_iLimitRegen           301393 non-null  float32
#  36  bms_pLimitDrive           301393 non-null  float32
#  37  bms_pLimitRegen           301393 non-null  float32
#  38  bcm_HvOnRequest           301384 non-null  float32
#  39  esc_vehicleSpeed          301393 non-null  float32
#  40  esc_vehicleSpeedValid     301393 non-null  float32
#  41  ac_ambientTemp            301393 non-null  float32
#  42  ac_ambientTempValid       301393 non-null  float32
#  43  vcu_highVoltageIndicator  301384 non-null  float32
#  44  bcm_HvOffRequest          301384 non-null  float32
#  45  BCM_EBS_State             301384 non-null  float32
# dtypes: float32(40), int64(1), object(5)
# memory usage: 62.1+ MB

# %%
data = data[(data["BCM_ebs_U_BATT"] > 3.) & (data["BCM_ebs_U_BATT"] < 18.)]
data.info()

# %%
pd.DataFrame(data["BCM_ebs_U_BATT"].value_counts()).sort_values(by='BCM_ebs_U_BATT')

# %%
import matplotlib.pyplot as plt
data[(data["BCM_ebs_U_BATT"] > 3.) & (data["BCM_ebs_U_BATT"] < 11.)].BCM_ebs_U_BATT.hist(bins=12, figsize=(5,3))
plt.show()

# %%
data_copy = data.copy()

data_copy['date'] = pd.to_datetime(data_copy["collect_ts"], unit='ms')

data_copy = data_copy.set_index("date")
data_copy
# Out:
#                                        vin     collect_ts
# date
# 2023-04-02 02:52:13.746  LM8F7D896NA007722  1680403933746  \
# 2023-04-02 02:52:14.746  LM8F7D896NA007722  1680403934746
# 2023-04-02 02:52:15.746  LM8F7D896NA007722  1680403935746
# 2023-04-02 02:52:16.746  LM8F7D896NA007722  1680403936746
# 2023-04-02 02:52:17.746  LM8F7D896NA007722  1680403937746
# ...                                    ...            ...
# 2023-04-24 05:43:37.922  LM8F7D896NA007722  1682315017922
# 2023-04-24 05:43:38.922  LM8F7D896NA007722  1682315018922
# 2023-04-24 05:43:39.922  LM8F7D896NA007722  1682315019922
# 2023-04-24 05:43:40.922  LM8F7D896NA007722  1682315020922
# 2023-04-02 02:52:14.746            0.0
# 2023-04-02 02:52:15.746            0.0
# 2023-04-02 02:52:16.746            0.0
# 2023-04-02 02:52:17.746            0.0
# ...                                ...
# 2023-04-24 05:43:37.922            0.0
# 2023-04-24 05:43:38.922            0.0
# 2023-04-24 05:43:39.922            0.0
# 2023-04-24 05:43:40.922            0.0
# 2023-04-24 05:43:41.922            0.0
#
# [301393 rows x 46 columns]

# %%
import matplotlib.pyplot as plt

data_copy["2023-04-02 00:00:00":"2023-04-24 22:00:00"][["BCM_ebs_U_BATT", "dcdc_realOutputVoltage"]].plot(grid=True, marker=".", figsize=(15, 3))

data_copy["2023-04-02 00:00:00":"2023-04-24 22:00:00"][["vcu_vehicleSpeed"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-02 00:00:00":"2023-04-24 22:00:00"][["bcm_12VBatterySOC"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-02 00:00:00":"2023-04-24 22:00:00"][["dcdc_realOutputCurrent"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-02 00:00:00":"2023-04-24 22:00:00"][["bms_SOC"]].plot(grid=True, marker=".", figsize=(15, 3))

# extra code – saves the figure for the book
plt.show()

# %% [markdown]
# 1. DC-DC 有输出的前提是高压上电
# 2. 当 DC-DC 有输出时，小电瓶电压会很快和其保持一致
# 3.

# %%
import matplotlib.pyplot as plt

data_copy["2023-04-08 00:00:00":"2023-04-09 09:10:00"][["BCM_ebs_U_BATT", "dcdc_realOutputVoltage"]].plot(grid=True, marker=".", figsize=(15, 3))

data_copy["2023-04-08 00:00:00":"2023-04-09 09:10:00"][["vcu_vehicleSpeed"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-08 00:00:00":"2023-04-09 09:10:00"][["dcdc_realOutputCurrent"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-08 00:00:00":"2023-04-09 09:10:00"][["BCM_ebs_SOC"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-08 00:00:00":"2023-04-09 09:10:00"][["bms_SOC"]].plot(grid=True, marker=".", figsize=(15, 3))

# extra code – saves the figure for the book
plt.show()

# %%
import matplotlib.pyplot as plt

data_copy["2023-04-24 00:00:00":"2023-04-24 05:10:00"][["BCM_ebs_U_BATT", "dcdc_realOutputVoltage"]].plot(grid=True, marker=".", figsize=(15, 3))

data_copy["2023-04-24 00:00:00":"2023-04-24 05:10:00"][["vcu_vehicleSpeed"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-24 00:00:00":"2023-04-24 05:10:00"][["dcdc_realOutputCurrent"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-24 00:00:00":"2023-04-24 05:10:00"][["BCM_ebs_SOC"]].plot(grid=True, marker=".", figsize=(15, 3))
data_copy["2023-04-24 00:00:00":"2023-04-24 05:10:00"][["bms_SOC"]].plot(grid=True, marker=".", figsize=(15, 3))

# extra code – saves the figure for the book
plt.show()
